# %% [markdown]
# <h1 align="center">Credit Risk Modeling Using Various Models - ID/X Partners</h1>

# %% [markdown]
# ###### By: [jihad akbar](https://github.com/jihadakbr) | Dataset: [Kaggle](https://drive.google.com/file/d/1wFnz5ozhqX0_FB123bagKWmDRFRF1S_a/view?usp=share_link)
# ###### You can see this notebook clearly using this link [nbviewer.org](https://nbviewer.org/github/jihadakbr/credit-score-prediction/blob/main/credit-risk-modeling-using-various-models.ipynb).

# %% [markdown]
# <div id="toc"><h1>Table of Contents</h1></div>
#
# <div id="backTotop" class="alert alert-block alert-info">
#     <ol>
#         <li><a href="#one">Problem Formulation</a>
#             <ol style="list-style-type:none;padding-left:0">
#                 <li>1.1 <a href="#problem">Business Understanding</a></li>
#                 <li>1.2 <a href="#prompt">Project Prompt</a></li>
#                 <li>1.3 <a href="#tools">Selecting Appropriate Tools</a></li>
#                 <li>1.4 <a href="#timeline">Determining the Data Science Project Workflow and Timeline</a></li>
#             </ol>
#         </li>
#         <li><a href="#two">Data Collecting</a></li>
#         <li><a href="#three">Data Understanding</a>
#             <ol style="list-style-type:none;padding-left:0">
#                 <li>3.1 <a href="#datasetcontent">Reviewing the Dataset's Content</a></li>
#             </ol>
#         </li>
#         <li><a href="#four">Data preprocessing</a>
#             <ol style="list-style-type:none;padding-left:0">
#                 <li>4.1 <a href="#libraries">Importing Required Libraries</a></li>
#                 <li>4.2 <a href="#reading">Importing and Reading the File</a></li>
#                 <li>4.3 <a href="#datadistribution">Analyzing Data Distribution</a></li>
#                 <li>4.4 <a href="#pythondropcols">Dropping Unnecessary Columns and Removing 70% Missing Values</a></li>
#                 <li>4.5 <a href="#dupvalues">Removing Duplicated Values</a></li>
#                 <li>4.6 <a href="#splittingtraintest">Splitting the Dataset into Training and Test Sets</a></li>
#                 <li>4.7 <a href="#pythondatatypes">Checking and Converting Datatypes</a></li>
#                 <li>4.8 <a href="#outliers">Detecting and Handling Outliers</a></li>
#                 <li>4.9 <a href="#missvalues">Data Imputation</a>
#                     <ol style="list-style-type:none;padding-left:1.75em">
#                         <li>4.9.1 <a href="#numvariables">Numerical Variables</a></li>
#                         <li>4.9.2 <a href="#catvariables">Categorical Variables</a></li>
#                     </ol>
#                 </li>
#                 <li>4.10 <a href="#dropsavecols">Dropping and Saving Columns</a></li>
#             </ol>
#         </li>
#         <li><a href="#five">Exploratory Data Analysis (EDA) and Data Visualization</a>
#             <ol style="list-style-type:none;padding-left:0">
#                 <li>5.1 <a href="#edadist">Analyzing Numerical Distribution</a></li>
#                 <li>5.2 <a href="#kdeplot">Kernel Density Estimate (KDE) Plot</a></li>
#                 <li>5.3 <a href="#edaplothist">Plotting Histograms of Selected Categorical Variables to Target Variable</a></li>
#                 <li>5.4 <a href="#edatarvarpro">Checking Target Variable Proportions</a></li>
#             </ol>
#         </li>
#         <li><a href="#six">Feature Selection and Engineering</a>
#             <ol style="list-style-type:none;padding-left:0">
#                 <li>6.1 <a href="#utilchisquare">Chi Square Test (Categorical Features)</a>
#                     <ol style="list-style-type:none;padding-left:1.75em">
#                         <li>6.1.1 <a href="#chitestdepend">Chi-Square test for dependency</a></li>
#                         <li>6.1.2 <a href="#dummencod">Dummy Encoding</a></li>
#                     </ol>
#                 </li>
#                 <li>6.2 <a href="#anovaa">ANOVA (Numerical Features)</a>
#                     <ol style="list-style-type:none;padding-left:1.75em">
#                         <li>6.2.1 <a href="#anovatest">ANOVA test for dependency</a></li>
#                         <li>6.2.2 <a href="#corrmatrix">Correlation Matrix</a></li>
#                     </ol>
#                 </li>
#             </ol>
#         </li>
#         <li><a href="#seven">Model Selection and Building</a>
#             <ol style="list-style-type:none;padding-left:0">
#                 <li>7.1 <a href="#trainml">Training the Machine Learning Model</a></li>
#                 <li>7.2 <a href="#selectml">Selecting the Machine Learning Model</a></li>
#                 <li>7.3 <a href="#featureimportance">Feature Importance</a></li>
#                 <li>7.4 <a href="#testml">Testing the Machine Learning Model</a></li>
#                 <li>7.5 <a href="#confmatrixauroctest">Confusion Matrix and AUROC on X_test Set</a></li>
#                 <li>7.6 <a href="#loancutoffs">Setting loan approval cut-offs</a></li>
#                 <li>7.7 <a href="#calmoneysavedandlosses">Calculating Money Saved and Losses in the X_test set</a></li>
#             </ol>
#         </li>
#     </ol>
# </div>

# %% [markdown]
# <div id="one">
#     <div style="font-size:25pt;color:red;font-weight:700;padding:20px 0;line-height:1.2">1. Problem Formulation</div>
#     <div style="text-align: right;"><a href="#toc" style="text-decoration:none;">↑ Table of Contents</a></div>
# </div>

# %% [markdown]
# <div id="problem">
#     <div style="font-size:20pt;font-weight:700;padding:20px 0;line-height:1.2">1.1 Business Understanding</div>
#     <div style="text-align: right;"><a href="#toc" style="text-decoration:none;">↑ Table of Contents</a></div>
# </div>

# %% [markdown]
# As the final task of your internship as a Data Scientist at **ID/X Partners**, this time you will be involved in a project for a lending company. You will collaborate with various other departments in this project to provide technological solutions for the company. You are asked to build a model that can predict credit risk using a dataset provided by the company, which consists of loan data that has been accepted and rejected. Additionally, you also need to prepare visual media to present the solution to the client. Make sure the visual media you create is clear, easy to read, and communicative. You can carry out this end-to-end solution development in your preferred programming language while adhering to the framework/methodology of Data Science.

# %% [markdown]
# <div id="prompt">
#     <div style="font-size:20pt;font-weight:700;padding:20px 0;line-height:1.2">1.2 Project Prompt</div>
#     <div style="text-align: right;"><a href="#toc" style="text-decoration:none;">↑ Table of Contents</a></div>
# </div>

# %% [markdown]
# 1. The provided dataset consists of one data file (in CSV format) and one data dictionary (in XLSX format) that contains information about each column in the data file. Please study the information about the data to understand the steps needed to prepare the data.
# 2. Prepare the tools you will use to assist you in completing the task, as explained in the prerequisites. Then, import the data to prepare for the task.
# 3. Complete the task and prepare all the files that you need to submit, referring to No. 6.
# 4. Combine the three files you have completed into a single ZIP folder titled "[Full Name]_VIX_ID/X Partners".
# 5. Submit your assignment only in the form of a ZIP folder according to the instructions in No. 4.
# 6. There are two submission scenarios based on the programming language you used to work on this final project. Please check below for the details:
#     * A. If you used R to work on this task, you need to submit:
#         * Code file in .R format
#         * R Markdown file in .Rmd format
#         * Infographic file as the presentation media for the end-to-end solution you created
#     * B. If you used Python to work on this task, you need to submit:
#         * Code file in .py format
#         * Python Notebook file in .ipynb format
#         * Infographic file as the presentation media for the end-to-end solution you created
#
# **Notes:** The submission output consists of three files (Python: .py, .ipynb, and ppt | R: .R, .Rmd, ppt), and the project should be submitted in the form of code (only script), markdown/python (including the steps), and one more PPT infographic along with its explanation.

# %% [markdown]
# <div id="tools">
#     <div style="font-size:20pt;font-weight:700;padding:20px 0;line-height:1.2">1.3 Selecting Appropriate Tools</div>
#     <div style="text-align: right;"><a href="#toc" style="text-decoration:none;">↑ Table of Contents</a></div>
# </div>

# %% [markdown]
# * Programming language: Python.
# * Data Tool: Jupyter Notebook.
# * Reporting Tool: Microsoft PowerPoint.

# %% [markdown]
# <div id="timeline">
#     <div style="font-size:20pt;font-weight:700;padding:20px 0;line-height:1.2">1.4 Determining the Data Science Project Workflow and Timeline</div>
#     <div style="text-align: right;"><a href="#toc" style="text-decoration:none;">↑ Table of Contents</a></div>
# </div>

# %% [markdown]
# Deadline: 4th June 2023 (a 1-month project)
#
# | No. | Workflow | Weight |
# |:---|:---|---|
# | 1 | Problem Formulation | 5% |
# | 2 | Data Collecting | 5% |
# | 3 | Data Understanding | 5% |
# | 4 | Data preprocessing | 20% |
# | 5 | Exploratory Data Analysis (EDA) and Data Visualization | 5% |
# | 6 | Feature Selection and Engineering | 30% |
# | 7 | Model Selection and Building | 30% |

# %% [markdown]
# <div id="two">
#     <div style="font-size:25pt;color:red;font-weight:700;padding:20px 0;line-height:1.2">2. Data Collecting</div>
#     <div style="text-align: right;"><a href="#toc" style="text-decoration:none;">↑ Table of Contents</a></div>
# </div>

# %% [markdown]
# I will use a dataset from [Kaggle](https://drive.google.com/file/d/1wFnz5ozhqX0_FB123bagKWmDRFRF1S_a/view?usp=share_link) that pertains to consumer loans granted from 2007 to 2014 by Lending Club, which is a peer-to-peer lending platform based in the United States.

# %% [markdown]
# <div id="three">
#     <div style="font-size:25pt;color:red;font-weight:700;padding:20px 0;line-height:1.2">3. Data Understanding</div>
#     <div style="text-align: right;"><a href="#toc" style="text-decoration:none;">↑ Table of Contents</a></div>
# </div>

# %% [markdown]
# <div id="datasetcontent">
#     <div style="font-size:20pt;font-weight:700;padding:20px 0;line-height:1.2">3.1 Reviewing the Dataset's Content</div>
#     <div style="text-align: right;"><a href="#toc" style="text-decoration:none;">↑ Table of Contents</a></div>
# </div>

# %% [markdown]
# I received a total of 2 files, which are named as follows:
# 1. loan_data_2007_2014.csv
# 2. LCDataDictionary.xlsx

# %% [markdown]
# The column description for the "loan_data_2007_2014.csv" file is provided below:
#
# <details>
#     <summary><code>Click here to show hidden text</code></summary>
#
# | No. | Row | Description |
# |:-:|:--|:--|
# |	1	|	id	|	A unique LC assigned ID for the loan listing.	|
# |	2	|	member_id	|	A unique LC assigned Id for the borrower member.	|
# |	3	|	loan_amnt	|	The listed amount of the loan applied for by the borrower. If at some point in time, the credit department reduces the loan amount, then it will be reflected in this value.	|
# |	4	|	funded_amnt	|	The total amount committed to that loan at that point in time.	|
# |	5	|	funded_amnt_inv	|	The total amount committed by investors for that loan at that point in time.	|
# |	6	|	term	|	The number of payments on the loan. Values are in months and can be either 36 or 60.	|
# |	7	|	int_rate	|	Interest Rate on the loan	|
# |	8	|	installment	|	The monthly payment owed by the borrower if the loan originates.	|
# |	9	|	grade	|	LC assigned loan grade	|
# |	10	|	sub_grade	|	LC assigned loan subgrade	|
# |	11	|	emp_title	|	The job title supplied by the Borrower when applying for the loan.*	|
# |	12	|	emp_length	|	Employment length in years. Possible values are between 0 and 10 where 0 means less than one year and 10 means ten or more years. 	|
# |	13	|	home_ownership	|	The home ownership status provided by the borrower during registration. Our values are: RENT, OWN, MORTGAGE, OTHER.	|
# |	14	|	annual_inc	|	The self-reported annual income provided by the borrower during registration.	|
# |	15	|	verification_status	|	the verification status of an individual borrower's financial information	|
# |	16	|	issue_d	|	The month which the loan was funded	|
# |	17	|	loan_status	|	Current status of the loan	|
# |	18	|	pymnt_plan	|	Indicates if a payment plan has been put in place for the loan	|
# |	19	|	url	|	URL for the LC page with listing data.	|
# |	20	|	desc	|	Loan description provided by the borrower	|
# |	21	|	purpose	|	A category provided by the borrower for the loan request. 	|
# |	22	|	title	|	The loan title provided by the borrower	|
# |	23	|	zip_code	|	The first 3 numbers of the zip code provided by the borrower in the loan application.	|
# |	24	|	addr_state	|	The state provided by the borrower in the loan application	|
# |	25	|	dti	|	A ratio calculated using the borrower’s total monthly debt payments on the total debt obligations, excluding mortgage and the requested LC loan, divided by the borrower’s self-reported monthly income.	|
# |	26	|	delinq_2yrs	|	The number of 30+ days past-due incidences of delinquency in the borrower's credit file for the past 2 years	|
# |	27	|	earliest_cr_line	|	The month the borrower's earliest reported credit line was opened	|
# |	28	|	inq_last_6mths	|	The number of inquiries in past 6 months (excluding auto and mortgage inquiries)	|
# |	29	|	mths_since_last_delinq	|	The number of months since the borrower's last delinquency.	|
# |	30	|	mths_since_last_record	|	The number of months since the last public record.	|
# |	31	|	open_acc	|	The number of open credit lines in the borrower's credit file.	|
# |	32	|	pub_rec	|	Number of derogatory public records	|
# |	33	|	revol_bal	|	Total credit revolving balance	|
# |	34	|	revol_util	|	Revolving line utilization rate, or the amount of credit the borrower is using relative to all available revolving credit.	|
# |	35	|	total_acc	|	The total number of credit lines currently in the borrower's credit file	|
# |	36	|	initial_list_status	|	The initial listing status of the loan. Possible values are – W, F	|
# |	37	|	out_prncp	|	Remaining outstanding principal for total amount funded	|
# |	38	|	out_prncp_inv	|	Remaining outstanding principal for portion of total amount funded by investors	|
# |	39	|	total_pymnt	|	Payments received to date for total amount funded	|
# |	40	|	total_pymnt_inv	|	Payments received to date for portion of total amount funded by investors	|
# |	41	|	total_rec_prncp	|	Principal received to date	|
# |	42	|	total_rec_int	|	Interest received to date	|
# |	43	|	total_rec_late_fee	|	Late fees received to date	|
# |	44	|	recoveries	|	post charge off gross recovery	|
# |	45	|	collection_recovery_fee	|	post charge off collection fee	|
# |	46	|	last_pymnt_d	|	Last month payment was received	|
# |	47	|	last_pymnt_amnt	|	Last total payment amount received	|
# |	48	|	next_pymnt_d	|	Next scheduled payment date	|
# |	49	|	last_credit_pull_d	|	The most recent month LC pulled credit for this loan	|
# |	50	|	collections_12_mths_ex_med	|	Number of collections in 12 months excluding medical collections	|
# |	51	|	mths_since_last_major_derog	|	Months since most recent 90-day or worse rating	|
# |	52	|	policy_code	|	publicly available policy_code=1, new products not publicly available policy_code=2	|
# |	53	|	application_type	|	Indicates whether the loan is an individual application or a joint application with two co-borrowers	|
# |	54	|	annual_inc_joint	|	The combined self-reported annual income provided by the co-borrowers during registration	|
# |	55	|	dti_joint	|	A ratio calculated using the co-borrowers' total monthly payments on the total debt obligations, excluding mortgages and the requested LC loan, divided by the co-borrowers' combined self-reported monthly income	|
# |	56	|	verification_status_joint	|	Joint loan applications where two or more individuals apply for a loan together	|
# |	57	|	acc_now_delinq	|	The number of accounts on which the borrower is now delinquent.	|
# |	58	|	tot_coll_amt	|	Total collection amounts ever owed	|
# |	59	|	tot_cur_bal	|	Total current balance of all accounts	|
# |	60	|	open_acc_6m	|	Number of open trades in last 6 months	|
# |	61	|	open_il_6m	|	Number of currently active installment trades	|
# |	62	|	open_il_12m	|	Number of installment accounts opened in past 12 months	|
# |	63	|	open_il_24m	|	Number of installment accounts opened in past 24 months	|
# |	64	|	mths_since_rcnt_il	|	Months since most recent installment accounts opened	|
# |	65	|	total_bal_il	|	Total current balance of all installment accounts	|
# |	66	|	il_util	|	Ratio of total current balance to high credit/credit limit on all install acct	|
# |	67	|	open_rv_12m	|	Number of revolving trades opened in past 12 months	|
# |	68	|	open_rv_24m	|	Number of revolving trades opened in past 24 months	|
# |	69	|	max_bal_bc	|	Maximum current balance owed on all revolving accounts	|
# |	70	|	all_util	|	Balance to credit limit on all trades	|
# |	71	|	total_rev_hi_lim  	|	Total revolving high credit/credit limit	|
# |	72	|	inq_fi	|	Number of personal finance inquiries	|
# |	73	|	total_cu_tl	|	Number of finance trades	|
# |	74	|	inq_last_12m	|	Number of credit inquiries in past 12 months	|
#
# \* Employer Title replaces Employer Name for all loans listed after 9/23/2013
#
# </details>

# %% [markdown]
# Redundant and Unnecessary columns for the machine learning process include:
#
# | No. | Row | Description |
# |:-:|:--|:--|
# |	1	|	id	|	A unique LC assigned ID for the loan listing.	|
# |	2	|	member_id	|	A unique LC assigned Id for the borrower member.	|
# |	10	|	sub_grade	|	LC assigned loan subgrade	|
# |	11	|	emp_title	|	The job title supplied by the Borrower when applying for the loan.*	|
# |	19	|	url	|	URL for the LC page with listing data.	|
# |	20	|	desc	|	Loan description provided by the borrower	|
# |	22	|	title	|	The loan title provided by the borrower	|
# |	23	|	zip_code	|	The first 3 numbers of the zip code provided by the borrower in the loan application.	|

# %% [markdown]
# Features that potentially have Time-based Leakage in the "loan_data_2007_2014.csv":
#
# | No. | Row | Description |
# |:-:|:--|:--|
# |	17	|	loan_status	|	Current status of the loan	|
# |	41	|	total_rec_prncp	|	Principal received to date	|
# |	43	|	total_rec_late_fee	|	Late fees received to date	|
# |	44	|	recoveries	|	post charge off gross recovery	|
# |	45	|	collection_recovery_fee	|	post charge off collection fee	|
# |	48	|	next_pymnt_d	|	Next scheduled payment date	|

# %% [markdown]
# By reviewing the business objectives, we can predict that the target variable will be imbalanced, and we will need to balance it using the "RepeatedStratifiedKFold" and "SMOTE" technique.

# %% [markdown]
# Target Variable Description:
# * Target variable = 0 → Rejected for a loan → Defaulter
# * Target variable = 1 → Accepted for a loan → Non-Defaulter

# %% [markdown]
# This objective belongs to the category of supervised learning, specifically **classification**.

# %% [markdown]
# ## Note
#
# I will modify the target variable by assigning the value 0 to indicate a defaulter and 1 to indicate a non-defaulter. This adjustment is intended to maintain consistency with the **credit-risk-modeling-using-a-scorecard.ipynb** file.

# %% [markdown]
# <div id="four">
#     <div style="font-size:25pt;color:red;font-weight:700;padding:20px 0;line-height:1.2">4. Data preprocessing</div>
#     <div style="text-align: right;"><a href="#toc" style="text-decoration:none;">↑ Table of Contents</a></div>
# </div>

# %% [markdown]
# <div id="libraries">
#     <div style="font-size:20pt;font-weight:700;padding:20px 0;line-height:1.2">4.1 Importing Required Libraries</div>
#     <div style="text-align: right;"><a href="#toc" style="text-decoration:none;">↑ Table of Contents</a></div>
# </div>

# %%
from utils2 import *

# %% [markdown]
# <div id="reading">
#     <div style="font-size:20pt;font-weight:700;padding:20px 0;line-height:1.2">4.2 Importing and Reading the File</div>
#     <div style="text-align: right;"><a href="#toc" style="text-decoration:none;">↑ Table of Contents</a></div>
# </div>

# %%
data = pd.read_csv("loan_data_2007_2014.csv",index_col=0)

# %% [markdown]
# <div id="datadistribution">
#     <div style="font-size:20pt;font-weight:700;padding:20px 0;line-height:1.2">4.3 Analyzing Data Distribution</div>
#     <div style="text-align: right;"><a href="#toc" style="text-decoration:none;">↑ Table of Contents</a></div>
# </div>

# %%
data.shape
# Out:
# (466285, 74)

# %%
column_check(data)
# Out:
#                   Unique Values Data Types  \
# id                       466285      int64
# member_id                466285      int64
# loan_amnt                  1352      int64
# funded_amnt                1354      int64
# funded_amnt_inv            9854    float64
# ...                         ...        ...
# all_util                      0    float64
# total_rev_hi_lim          14612    float64
# inq_fi                        0    float64
# total_cu_tl                   0    float64
# inq_last_12m                  0    float64
#
#                                                         Examples
# id                19677589, 29755527, 1343334, 33131681, 3293168
# member_id         21900299, 32278795, 1588314, 35775007, 4066358
# loan_amnt                      32500, 11000, 30000, 14400, 15000
# funded_amnt                    32500, 11000, 30000, 14400, 15000
# funded_amnt_inv      32500.0, 11000.0, 30000.0, 14400.0, 14900.0
# ...

# %% [markdown]
# <div id="pythondropcols">
#     <div style="font-size:20pt;font-weight:700;padding:20px 0;line-height:1.2">4.4 Dropping Unnecessary Columns and Removing > 70% Missing Values</div>
#     <div style="text-align: right;"><a href="#toc" style="text-decoration:none;">↑ Table of Contents</a></div>
# </div>

# %%
columns_list = ["member_id","sub_grade","emp_title","url","desc","title","zip_code","total_rec_prncp",
                "total_rec_late_fee","recoveries","collection_recovery_fee","next_pymnt_d"]

# %%
missing_cols = data.columns[data.isnull().any()].tolist()
missing_percent = data[missing_cols].isnull().sum()* 100 / len(data)
columns_to_drop = missing_percent[missing_percent > 70] # Missing values' treshold = 70%
print(columns_to_drop)
# Out:
# desc                            72.981546
# mths_since_last_record          86.566585
# mths_since_last_major_derog     78.773926
# annual_inc_joint               100.000000
# dti_joint                      100.000000
# verification_status_joint      100.000000
# open_acc_6m                    100.000000
# open_il_6m                     100.000000
# open_il_12m                    100.000000
# open_il_24m                    100.000000
# mths_since_rcnt_il             100.000000
# total_bal_il                   100.000000
# il_util                        100.000000
# open_rv_12m                    100.000000
# open_rv_24m                    100.000000
# max_bal_bc                     100.000000
# all_util                       100.000000
# inq_fi                         100.000000
# total_cu_tl                    100.000000
# inq_last_12m                   100.000000
# dtype: float64

# %%
columns_list.extend(columns_to_drop.index.tolist())

# %%
col_to_drop(data, columns_list)

# %%
data.shape
# Out:
# (466285, 43)

# %% [markdown]
# <div id="dupvalues">
#     <div style="font-size:20pt;font-weight:700;padding:20px 0;line-height:1.2">4.5 Removing Duplicated Values</div>
#     <div style="text-align: right;"><a href="#toc" style="text-decoration:none;">↑ Table of Contents</a></div>
# </div>

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# <div id="splittingtraintest">
#     <div style="font-size:20pt;font-weight:700;padding:20px 0;line-height:1.2">4.6 Splitting the Dataset into Training and Test Sets</div>
#     <div style="text-align: right;"><a href="#toc" style="text-decoration:none;">↑ Table of Contents</a></div>
# </div>

# %%
X = data.drop(columns="loan_status", axis=1)
y = data["loan_status"]

# %%
X_train, X_test, y_train, y_test = model_selection.train_test_split(X, y, test_size = 0.20, random_state = random_state_, stratify = y)

# %%
print(f"training shapes: {X_train.shape}, {y_train.shape}")
print(f"testing shapes: {X_test.shape}, {y_test.shape}")
# Out:
# training shapes: (373028, 42), (373028,)
# testing shapes: (93257, 42), (93257,)

# %%
train = pd.concat([X_train, y_train], axis=1)
test = pd.concat([X_test, y_test], axis=1)

# %%
train.shape, test.shape
# Out:
# ((373028, 43), (93257, 43))

# %% [markdown]
# <div id="pythondatatypes">
#     <div style="font-size:20pt;font-weight:700;padding:20px 0;line-height:1.2">4.7 Checking and Converting Datatypes</div>
#     <div style="text-align: right;"><a href="#toc" style="text-decoration:none;">↑ Table of Contents</a></div>
# </div>

# %%
numeric_count_train = len(train.select_dtypes(include="number").columns)
object_count_train = len(train.select_dtypes(include="object").columns)
numeric_count_test = len(test.select_dtypes(include="number").columns)
object_count_test = len(test.select_dtypes(include="object").columns)

print("Train Numeric column count:", numeric_count_train)
print("Train Object column count:", object_count_train)
print("Test Numeric column count:", numeric_count_test)
print("Test Object column count:", object_count_test)
# Out:
# Train Numeric column count: 28
# Train Object column count: 15
# Test Numeric column count: 28
# Test Object column count: 15

# %%
column_check(train)
# Out:
#                             Unique Values Data Types  \
# id                                 373028      int64
# loan_amnt                            1340      int64
# funded_amnt                          1342      int64
# funded_amnt_inv                      8153    float64
# term                                    2     object
# int_rate                              502    float64
# installment                         51407    float64
# grade                                   7     object
# emp_length                             11     object
# home_ownership                          6     object
# annual_inc                          26984    float64
# verification_status                     3     object
# issue_d                                91     object
# pymnt_plan                              2     object
# purpose                                14     object
# addr_state                             50     object
# dti                                  3996    float64
# ...

# %% [markdown]
# ### 1. loan_status

# %%
train["loan_status"].value_counts()
# Out:
# Current                                                179381
# Fully Paid                                             147791
# Charged Off                                             33980
# Late (31-120 days)                                       5520
# In Grace Period                                          2517
# Does not meet the credit policy. Status:Fully Paid       1590
# Late (16-30 days)                                         974
# Default                                                   666
# Does not meet the credit policy. Status:Charged Off       609
# Name: loan_status, dtype: int64

# %%
# the expression assigns 0 to the values in data that match 'Charged Off', 'Default', 'Late (31-120 days)', etc. ...
# and assigns 1 to all other values.
train["target"] = np.where(train.loc[:, "loan_status"].isin(["Charged Off", "Default", "Late (31-120 days)",
                                                                       "Does not meet the credit policy. Status:Charged Off"]), 0, 1)
test["target"] = np.where(test.loc[:, "loan_status"].isin(["Charged Off", "Default", "Late (31-120 days)",
                                                                       "Does not meet the credit policy. Status:Charged Off"]), 0, 1)

train.drop(columns = ["loan_status"], inplace = True)
test.drop(columns = ["loan_status"], inplace = True)

# %%
train["target"].value_counts()
# Out:
# 1    332253
# 0     40775
# Name: target, dtype: int64

# %%
test["target"].value_counts()
# Out:
# 1    83064
# 0    10193
# Name: target, dtype: int64

# %% [markdown]
# ### 2. emp_length

# %%
train["emp_length"].unique()
# Out:
# array(['10+ years', '2 years', '3 years', '< 1 year', '4 years',
#        '8 years', '1 year', '9 years', nan, '7 years', '5 years',
#        '6 years'], dtype=object)

# %%
emp_length_converter(train, "emp_length")
emp_length_converter(test, "emp_length")

# %%
train["emp_length"].unique()
# Out:
# array([10.,  2.,  3.,  0.,  4.,  8.,  1.,  9.,  7.,  5.,  6.])

# %%
test["emp_length"].unique()
# Out:
# array([ 0., 10.,  4.,  6.,  1.,  3.,  2.,  7.,  9.,  5.,  8.])

# %% [markdown]
# ### 3. date columns

# %%
date_columns(train, "earliest_cr_line")
date_columns(train, "issue_d")
date_columns(train, "last_pymnt_d")
date_columns(train, "last_credit_pull_d")

print(train["mths_since_earliest_cr_line"].describe(), "\n")
print(train["mths_since_issue_d"].describe(), "\n")
print(train["mths_since_last_pymnt_d"].describe(), "\n")
print(train["mths_since_last_credit_pull_d"].describe())
# Out:
# count    373001.000000
# mean        308.353659
# std          86.397260
# min         139.000000
# 25%         249.000000
# 50%         292.000000
# 75%         351.000000
# max         653.000000
# Name: mths_since_earliest_cr_line, dtype: float64
#
# count    373028.000000
# mean        117.239631
# std          14.341962
# min         102.000000
# 25%         107.000000
# 50%         113.000000
# 75%         123.000000
# max         192.000000
# Name: mths_since_issue_d, dtype: float64
#
# count    372725.000000
# mean         97.288781
# std          12.798473
# min          89.000000
# 25%          89.000000
# 50%          90.000000
# 75%         101.000000
# max         186.000000
# Name: mths_since_last_pymnt_d, dtype: float64
#
# count    372999.000000
# mean         93.045199
# std           9.639320
# min          89.000000
# 25%          89.000000
# 50%          89.000000
# 75%          91.000000
# max         193.000000
# ...

# %%
date_columns(test, "earliest_cr_line")
date_columns(test, "issue_d")
date_columns(test, "last_pymnt_d")
date_columns(test, "last_credit_pull_d")

print(test["mths_since_earliest_cr_line"].describe(), "\n")
print(test["mths_since_issue_d"].describe(), "\n")
print(test["mths_since_last_pymnt_d"].describe(), "\n")
print(test["mths_since_last_credit_pull_d"].describe())
# Out:
# count    93255.000000
# mean       308.512230
# std         86.712389
# min        140.000000
# 25%        250.000000
# 50%        292.000000
# 75%        352.000000
# max        653.000000
# Name: mths_since_earliest_cr_line, dtype: float64
#
# count    93257.000000
# mean       117.317413
# std         14.332830
# min        102.000000
# 25%        107.000000
# 50%        113.000000
# 75%        123.000000
# max        192.000000
# Name: mths_since_issue_d, dtype: float64
#
# count    93184.000000
# mean        97.316717
# std         12.855542
# min         89.000000
# 25%         89.000000
# 50%         90.000000
# 75%        101.000000
# max        186.000000
# Name: mths_since_last_pymnt_d, dtype: float64
#
# count    93244.000000
# mean        93.047145
# std          9.624878
# min         89.000000
# 25%         89.000000
# 50%         89.000000
# 75%         91.000000
# max        193.000000
# Name: mths_since_last_credit_pull_d, dtype: float64

# %% [markdown]
# ### 4. term

# %%
loan_term_converter(train, "term")
loan_term_converter(test, "term")

# %%
train["term"].value_counts()
# Out:
# 36    270346
# 60    102682
# Name: term, dtype: int64

# %%
test["term"].value_counts()
# Out:
# 36    67607
# 60    25650
# Name: term, dtype: int64

# %% [markdown]
# ---

# %% [markdown]
# ### intruders

# %%
train_num = train.select_dtypes(include = "number")
test_num = test.select_dtypes(include = "number")

# %%
train_object = train.select_dtypes(include = "object")
test_object = test.select_dtypes(include = "object")

# %% [markdown]
# ### Uncomment the following codes if you want to check it yourself.

# %%
# column_check(train_num)

# %%
# column_check(train_object)

# %%
# column_check(test_num)

# %%
# column_check(test_object)

# %% [markdown]
# Based on the table above, the **numerical inputs** still maintain the correct data types (integer or float). This indicates that there are no intruders such as strings present.

# %%
# object_input_check(train, train_object)

# %%
# object_input_check(test, test_object)

# %% [markdown]
# <div id="outliers">
#     <div style="font-size:20pt;font-weight:700;padding:20px 0;line-height:1.2">4.8 Detecting and Handling Outliers</div>
#     <div style="text-align: right;"><a href="#toc" style="text-decoration:none;">↑ Table of Contents</a></div>
# </div>

# %%
num_cols = train.select_dtypes(include="number").columns.tolist()
outlier_percentage = count_outliers(train, num_cols)
print(outlier_percentage)
# Out:
# {'id': '0.00%', 'loan_amnt': '0.00%', 'funded_amnt': '0.00%', 'funded_amnt_inv': '0.00%', 'term': '0.00%', 'int_rate': '1.05%', 'installment': '2.50%', 'emp_length': '0.00%', 'annual_inc': '4.15%', 'dti': '0.01%', 'delinq_2yrs': '17.88%', 'inq_last_6mths': '7.90%', 'mths_since_last_delinq': '0.02%', 'open_acc': '2.25%', 'pub_rec': '13.18%', 'revol_bal': '4.92%', 'revol_util': '0.00%', 'total_acc': '1.86%', 'out_prncp': '5.01%', 'out_prncp_inv': '5.02%', 'total_pymnt': '4.06%', 'total_pymnt_inv': '4.06%', 'total_rec_int': '6.69%', 'last_pymnt_amnt': '15.06%', 'collections_12_mths_ex_med': '0.84%', 'policy_code': '0.00%', 'acc_now_delinq': '0.37%', 'tot_coll_amt': '10.70%', 'tot_cur_bal': '2.64%', 'total_rev_hi_lim': '4.61%', 'target': '10.93%', 'mths_since_earliest_cr_line': '3.26%', 'mths_since_issue_d': '5.03%', 'mths_since_last_pymnt_d': '6.94%', 'mths_since_last_credit_pull_d': '20.07%'}

# %%
# # Uncomment this code to see all graphs
# fig, axs = outliers_graph(train, num_cols)

# %% [markdown]
# Selected outliers to be removed:
# * "revol_util"
# * "collections_12_mths_ex_med"
# * "tot_coll_amt"
# * "total_rev_hi_lim"

# %%
selected_cols = ["revol_util","collections_12_mths_ex_med","tot_coll_amt","total_rev_hi_lim"]
fig, axs = outliers_graph(train, selected_cols)

# %%
# Remove outliers in "revol_util" column
filtered_data = train[(train["revol_util"] >= 200) & (train["revol_util"] <= 2000)]

max_value = filtered_data["revol_util"].max()
print("Max:",max_value)

count = filtered_data["revol_util"].count()
print("Count:",count)
# Out:
# Max: 892.3
# Count: 2

# %%
train = train[train["revol_util"] < 200]

# %%
# Remove outliers in "collections_12_mths_ex_med" column
filtered_data = train[(train["collections_12_mths_ex_med"] >= 8) & (train["collections_12_mths_ex_med"] <= 30)]

max_value = filtered_data["collections_12_mths_ex_med"].max()
print("Max:",max_value)

count = filtered_data["collections_12_mths_ex_med"].count()
print("Count:",count)
# Out:
# Max: 20.0
# Count: 2

# %%
train = train[train["collections_12_mths_ex_med"] < 8]

# %%
# Remove outliers in "tot_coll_amt" column
filtered_data = train[(train["tot_coll_amt"] >= 200000) & (train["tot_coll_amt"] <= 20000000)]

max_value = filtered_data["tot_coll_amt"].max()
print("Max:",max_value)

count = filtered_data["tot_coll_amt"].count()
print("Count:",count)
# Out:
# Max: 9152545.0
# Count: 1

# %%
train = train[train["tot_coll_amt"] < 200000]

# %%
# Remove outliers in "total_rev_hi_lim" column
filtered_data = train[(train["total_rev_hi_lim"] >= 2000000) & (train["total_rev_hi_lim"] <= 12000000)]

max_value = filtered_data["total_rev_hi_lim"].max()
print("Max:",max_value)

count = filtered_data["total_rev_hi_lim"].count()
print("Count:",count)
# Out:
# Max: 9999999.0
# Count: 3

# %%
train = train[train["total_rev_hi_lim"] < 2000000]

# %%
selected_cols = ["revol_util","collections_12_mths_ex_med","tot_coll_amt","total_rev_hi_lim"]
fig, axs = outliers_graph(train, selected_cols)

# %%
train.shape, test.shape
# Out:
# ((316647, 43), (93257, 43))

# %% [markdown]
# <div id="missvalues">
#     <div style="font-size:20pt;font-weight:700;padding:20px 0;line-height:1.2">4.9 Data Imputation</div>
#     <div style="text-align: right;"><a href="#toc" style="text-decoration:none;">↑ Table of Contents</a></div>
# </div>

# %%
train.isnull().sum().sum(), test.isnull().sum().sum()
# Out:
# (164194, 92549)

# %% [markdown]
# <div id="numvariables">
#     <div style="font-size:18pt;font-weight:700;padding:20px 0;line-height:1.2">4.9.1 Numerical Variables</div>
#     <div style="text-align: right;"><a href="#toc" style="text-decoration:none;">↑ Table of Contents</a></div>
# </div>

# %%
missing_cols_num_train = train.loc[:, train.isnull().any()].select_dtypes(include = "number")
missing_cols_num_test = test.loc[:, test.isnull().any()].select_dtypes(include = "number")

# %%
missing_cols_num_train.isnull().sum().sum(), missing_cols_num_test.isnull().sum().sum()
# Out:
# (164194, 92549)

# %%
missing_cols_num_train.head()
# Out:
#         mths_since_last_delinq  mths_since_last_pymnt_d  \
# 237449                    42.0                     89.0
# 441066                     7.0                    107.0
# 126686                     9.0                    117.0
# 337970                     NaN                    104.0
# 440472                     NaN                     89.0
#
#         mths_since_last_credit_pull_d
# 237449                           89.0
# 441066                           89.0
# 126686                          112.0
# 337970                           99.0
# 440472                           89.0

# %%
means_train = missing_cols_num_train.mean()
means_test = missing_cols_num_test.mean()

# %%
missing_cols_num_train.fillna(means_train, inplace=True)
missing_cols_num_test.fillna(means_test, inplace=True)

# %%
missing_cols_num_train.head()
# Out:
#         mths_since_last_delinq  mths_since_last_pymnt_d  \
# 237449               42.000000                     89.0
# 441066                7.000000                    107.0
# 126686                9.000000                    117.0
# 337970               33.838321                    104.0
# 440472               33.838321                     89.0
#
#         mths_since_last_credit_pull_d
# 237449                           89.0
# 441066                           89.0
# 126686                          112.0
# 337970                           99.0
# 440472                           89.0

# %%
# check
train["mths_since_last_delinq"].mean()
# Out:
# 33.83832072567705

# %%
missing_cols_num_train.isnull().sum().sum(), missing_cols_num_test.isnull().sum().sum()
# Out:
# (0, 0)

# %%
train.drop(columns=missing_cols_num_train, axis=1, inplace = True)
test.drop(columns=missing_cols_num_test, axis=1, inplace = True)

# %%
train = pd.concat([train, missing_cols_num_train], axis=1)
test = pd.concat([test, missing_cols_num_test], axis=1)

# %%
train.isnull().sum().sum(), test.isnull().sum().sum()
# Out:
# (0, 0)

# %% [markdown]
# <div id="catvariables">
#     <div style="font-size:18pt;font-weight:700;padding:20px 0;line-height:1.2">4.9.2 Categorical Variables</div>
#     <div style="text-align: right;"><a href="#toc" style="text-decoration:none;">↑ Table of Contents</a></div>
# </div>

# %%
missing_cols_cat_train = train.loc[:, train.isnull().any()].select_dtypes(include = "object")
missing_cols_cat_test = test.loc[:, test.isnull().any()].select_dtypes(include = "object")

# %%
missing_cols_cat_train.isnull().sum().sum(), missing_cols_cat_test.isnull().sum().sum()
# Out:
# (0.0, 0.0)

# %%
train.isnull().sum().sum(), test.isnull().sum().sum()
# Out:
# (0, 0)

# %% [markdown]
# <div id="dropsavecols">
#     <div style="font-size:20pt;font-weight:700;padding:20px 0;line-height:1.2">4.10 Dropping and Saving Columns</div>
#     <div style="text-align: right;"><a href="#toc" style="text-decoration:none;">↑ Table of Contents</a></div>
# </div>

# %%
IDs = test["id"]
Loan_Amount = test["loan_amnt"]

# %%
train = train.drop(columns="id", axis=1)
test = test.drop(columns="id", axis=1)

# %%
print(f"training shapes: {train.shape}")
print(f"testing shapes: {test.shape}")
# Out:
# training shapes: (316647, 42)
# testing shapes: (93257, 42)

# %% [markdown]
# <div id="five">
#     <div style="font-size:25pt;color:red;font-weight:700;padding:20px 0;line-height:1.2">5. Exploratory Data Analysis (EDA) and Data Visualization</div>
#     <div style="text-align: right;"><a href="#toc" style="text-decoration:none;">↑ Table of Contents</a></div>
# </div>

# %% [markdown]
# <div id="edadist">
#     <div style="font-size:20pt;font-weight:700;padding:20px 0;line-height:1.2">5.1 Analyzing Numerical Distribution</div>
#     <div style="text-align: right;"><a href="#toc" style="text-decoration:none;">↑ Table of Contents</a></div>
# </div>

# %%
# # All Columns
# plot_histograms(train, train.select_dtypes(include="number").columns)

# %%
selected_cols = ["loan_amnt","funded_amnt","funded_amnt_inv","installment",
                 "emp_length","revol_util","total_pymnt_inv","total_acc",
                "int_rate","dti","total_pymnt","mths_since_last_pymnt_d"]

# %%
plot_histograms(train, selected_cols)

# %% [markdown]
# <div id="kdeplot">
#     <div style="font-size:20pt;font-weight:700;padding:20px 0;line-height:1.2">5.2 Kernel Density Estimate (KDE) Plot</div>
#     <div style="text-align: right;"><a href="#toc" style="text-decoration:none;">↑ Table of Contents</a></div>
# </div>

# %%
# # All Columns
# plot_kdeplots(train, train.select_dtypes(include="number").columns, "target")

# %%
selected_cols = ["int_rate","dti","total_pymnt","mths_since_last_pymnt_d"]

# %%
plot_kdeplots(train, selected_cols, "target")

# %% [markdown]
# <div id="edaplothist">
#     <div style="font-size:20pt;font-weight:700;padding:20px 0;line-height:1.2">5.3 Plotting Histograms of Selected Categorical Variables to Target Variable</div>
#     <div style="text-align: right;"><a href="#toc" style="text-decoration:none;">↑ Table of Contents</a></div>
# </div>

# %%
cat_dist(train, "grade", "target", "Defaulter", "Non-Defaulter", 0)

# %%
cat_dist(train, "home_ownership", "target", "Defaulter", "Non-Defaulter", 1, 0)
# Out:
# posx and posy should be finite values
# posx and posy should be finite values

# %%
cat_dist(train, "verification_status", "target", "Defaulter", "Non-Defaulter", 2, 0.05, "center right")

# %%
cat_dist(train, "pymnt_plan", "target", "Defaulter", "Non-Defaulter", 3, 0.1)

# %%
cat_dist(train, "purpose", "target", "Defaulter", "Non-Defaulter", 4, 0.02, x_label_rotation=70, custom="vertical")

# %% [markdown]
# <div id="edatarvarpro">
#     <div style="font-size:20pt;font-weight:700;padding:20px 0;line-height:1.2">5.4 Checking Target Variable Proportions</div>
#     <div style="text-align: right;"><a href="#toc" style="text-decoration:none;">↑ Table of Contents</a></div>
# </div>

# %%
target_dist(train, "target", "Defaulter", "Non-Defaulter")

# %% [markdown]
# <div id="six">
#     <div style="font-size:25pt;color:red;font-weight:700;padding:20px 0;line-height:1.2">6. Feature Selection and Engineering</div>
#     <div style="text-align: right;"><a href="#toc" style="text-decoration:none;">↑ Table of Contents</a></div>
# </div>

# %%
numeric_count_train = len(train.select_dtypes(include="number").columns)
object_count_train = len(train.select_dtypes(include="object").columns)
numeric_count_test = len(test.select_dtypes(include="number").columns)
object_count_test = len(test.select_dtypes(include="object").columns)

print("Train Numeric column count:", numeric_count_train)
print("Train Object column count:", object_count_train)
print("Test Numeric column count:", numeric_count_test)
print("Test Object column count:", object_count_test)
# Out:
# Train Numeric column count: 34
# Train Object column count: 8
# Test Numeric column count: 34
# Test Object column count: 8

# %%
X_train = train.drop(columns="target", axis=1)
y_train = train["target"]
X_test = test.drop(columns="target", axis=1)
y_test = test["target"]

# %%
print(f"training shapes: {X_train.shape}, {y_train.shape}")
print(f"testing shapes: {X_test.shape}, {y_test.shape}")
# Out:
# training shapes: (316647, 41), (316647,)
# testing shapes: (93257, 41), (93257,)

# %% [markdown]
# <div id="utilchisquare">
#     <div style="font-size:20pt;font-weight:700;padding:20px 0;line-height:1.2">6.1 Chi Square Test (Categorical Features)</div>
#     <div style="text-align: right;"><a href="#toc" style="text-decoration:none;">↑ Table of Contents</a></div>
# </div>

# %% [markdown]
# <div id="chitestdepend">
#     <div style="font-size:18pt;font-weight:700;padding:20px 0;line-height:1.2">6.1.1 Chi-Square test for dependency</div>
#     <div style="text-align: right;"><a href="#toc" style="text-decoration:none;">↑ Table of Contents</a></div>
# </div>

# %%
X_train_cat = X_train.select_dtypes(include = "object").copy()

# %%
chi2_result = chi_square_test(X_train_cat, y_train)
chi2_result
# Out:
#                Feature   p-value         interpret test-statistic  \
# 0                grade  0.000000            Dependent (reject H0)
# 1       home_ownership  0.000000            Dependent (reject H0)
# 2  verification_status  0.000000            Dependent (reject H0)
# 3              purpose  0.000000            Dependent (reject H0)
# 4           addr_state  0.000000            Dependent (reject H0)
# 5  initial_list_status  0.000000            Dependent (reject H0)
# 6           pymnt_plan  0.069312  Independent (fail to reject H0)
# 7     application_type  1.000000  Independent (fail to reject H0)
#
#                  interpret p-value
# 0            Dependent (reject H0)
# 1            Dependent (reject H0)
# 2            Dependent (reject H0)
# 3            Dependent (reject H0)
# 4            Dependent (reject H0)
# 5            Dependent (reject H0)
# 6  Independent (fail to reject H0)
# 7  Independent (fail to reject H0)

# %%
# columns_list = chi2_result["Feature"].iloc[4:].tolist()

# %%
columns_list = ["pymnt_plan","application_type"]

# %%
col_to_drop(X_train, columns_list)
col_to_drop(X_test, columns_list)

# %%
X_train.shape, X_test.shape
# Out:
# ((316647, 39), (93257, 39))

# %% [markdown]
# <div id="dummencod">
#     <div style="font-size:18pt;font-weight:700;padding:20px 0;line-height:1.2">6.1.2 Dummy Encoding</div>
#     <div style="text-align: right;"><a href="#toc" style="text-decoration:none;">↑ Table of Contents</a></div>
# </div>

# %%
dummy_cols = ["grade","home_ownership","verification_status","purpose","addr_state","initial_list_status"]

# %%
X_train = dummy_creation(X_train, dummy_cols)
X_test = dummy_creation(X_test, dummy_cols)

# %%
col_to_drop(X_train, dummy_cols)
col_to_drop(X_test, dummy_cols)

# %%
X_train.shape, X_test.shape
# Out:
# ((316647, 108), (93257, 107))

# %%
X_train.head(1)
# Out:
#         loan_amnt  funded_amnt  funded_amnt_inv  term  int_rate  installment  \
# 237449      23975        23975          23975.0    60     12.99       545.39
#
#         emp_length  annual_inc    dti  delinq_2yrs  ...  addr_state:TN  \
# 237449        10.0     48000.0  25.05          0.0  ...              0
#
#         addr_state:TX  addr_state:UT  addr_state:VA  addr_state:VT  \
# 237449              0              0              0              0
#
#         addr_state:WA  addr_state:WI  addr_state:WV  addr_state:WY  \
# 237449              0              0              0              0
#
#         initial_list_status:w
# 237449                      1
#
# [1 rows x 108 columns]

# %%
X_test.head(1)
# Out:
#        loan_amnt  funded_amnt  funded_amnt_inv  term  int_rate  installment  \
# 72790       6000         6000           6000.0    36     17.76        216.2
#
#        emp_length  annual_inc    dti  revol_bal  ...  addr_state:TN  \
# 72790         0.0     70000.0  24.65      17416  ...              0
#
#        addr_state:TX  addr_state:UT  addr_state:VA  addr_state:VT  \
# 72790              0              0              0              0
#
#        addr_state:WA  addr_state:WI  addr_state:WV  addr_state:WY  \
# 72790              0              0              0              0
#
#        initial_list_status:w
# 72790                      0
#
# [1 rows x 107 columns]

# %%
X_test = X_test.reindex(labels=X_train.columns, axis=1, fill_value=0)

# %%
X_train.shape, X_test.shape
# Out:
# ((316647, 108), (93257, 108))

# %% [markdown]
# <div id="anovaa">
#     <div style="font-size:20pt;font-weight:700;padding:20px 0;line-height:1.2">6.2 ANOVA (Numerical Features)</div>
#     <div style="text-align: right;"><a href="#toc" style="text-decoration:none;">↑ Table of Contents</a></div>
# </div>

# %%
X_train.columns[0]
# Out:
# 'loan_amnt'

# %%
X_train.columns[32]
# Out:
# 'mths_since_last_credit_pull_d'

# %%
X_train.iloc[:, 0:33].head(1)
# Out:
#         loan_amnt  funded_amnt  funded_amnt_inv  term  int_rate  installment  \
# 237449      23975        23975          23975.0    60     12.99       545.39
#
#         emp_length  annual_inc    dti  delinq_2yrs  ...  policy_code  \
# 237449        10.0     48000.0  25.05          0.0  ...            1
#
#         acc_now_delinq  tot_coll_amt  tot_cur_bal  total_rev_hi_lim  \
# 237449             0.0           0.0      20191.0           16500.0
#
#         mths_since_earliest_cr_line  mths_since_issue_d  \
# 237449                        343.0               102.0
#
#         mths_since_last_delinq  mths_since_last_pymnt_d  \
# 237449                    42.0                     89.0
#
#         mths_since_last_credit_pull_d
# 237449                           89.0
#
# [1 rows x 33 columns]

# %%
X_test.iloc[:, 0:33].head(1)
# Out:
#        loan_amnt  funded_amnt  funded_amnt_inv  term  int_rate  installment  \
# 72790       6000         6000           6000.0    36     17.76        216.2
#
#        emp_length  annual_inc    dti  delinq_2yrs  ...  policy_code  \
# 72790         0.0     70000.0  24.65          1.0  ...            1
#
#        acc_now_delinq  tot_coll_amt  tot_cur_bal  total_rev_hi_lim  \
# 72790             0.0         218.0     302285.0           26500.0
#
#        mths_since_earliest_cr_line  mths_since_issue_d  \
# 72790                        281.0               116.0
#
#        mths_since_last_delinq  mths_since_last_pymnt_d  \
# 72790                     5.0                     90.0
#
#        mths_since_last_credit_pull_d
# 72790                           89.0
#
# [1 rows x 33 columns]

# %%
X_train_num = X_train.iloc[:, 0:33].copy()

# %% [markdown]
# <div id="anovatest">
#     <div style="font-size:18pt;font-weight:700;padding:20px 0;line-height:1.2">6.2.1 ANOVA test for dependency</div>
#     <div style="text-align: right;"><a href="#toc" style="text-decoration:none;">↑ Table of Contents</a></div>
# </div>

# %%
ANOVA_F_table = calculate_ANOVA_F_table(X_train_num, y_train)
ANOVA_F_table
# Out:
#                 Numerical_Feature       F-Score      p values  \
# 0         mths_since_last_pymnt_d  34771.748074  0.000000e+00
# 1                 total_pymnt_inv  11443.421122  0.000000e+00
# 2                     total_pymnt  11443.299083  0.000000e+00
# 3   mths_since_last_credit_pull_d  10564.829076  0.000000e+00
# 4                        int_rate  10426.783091  0.000000e+00
# 5                       out_prncp   8722.849309  0.000000e+00
# 6                   out_prncp_inv   8721.643132  0.000000e+00
# 7                 last_pymnt_amnt   8149.877158  0.000000e+00
# 8              mths_since_issue_d   2439.945264  0.000000e+00
# 9                             dti   1188.714074  0.000000e+00
# 10                 inq_last_6mths   1178.152204  0.000000e+00
# 11                           term    976.500330  0.000000e+00
# 12                    tot_cur_bal    799.641716  0.000000e+00
# 13                     annual_inc    690.046541  0.000000e+00
# ...

# %% [markdown]
# For the sake of simplicity, we will keep only the top 20 features and calculate pair-wise correlations between them

# %%
# columns_list = ANOVA_F_table["Numerical_Feature"].iloc[20:].tolist()

# %%
columns_list = ["mths_since_last_delinq","collections_12_mths_ex_med","open_acc","acc_now_delinq","policy_code"]

# %%
col_to_drop(X_train, columns_list)
col_to_drop(X_test, columns_list)

# %%
X_train.shape, X_test.shape
# Out:
# ((316647, 103), (93257, 103))

# %% [markdown]
# <div id="corrmatrix">
#     <div style="font-size:18pt;font-weight:700;padding:20px 0;line-height:1.2">6.2.2 Correlation Matrix</div>
#     <div style="text-align: right;"><a href="#toc" style="text-decoration:none;">↑ Table of Contents</a></div>
# </div>

# %%
train_features = ANOVA_F_table.iloc[:28,0].tolist()

# %%
train_features
# Out:
# ['mths_since_last_pymnt_d',
#  'total_pymnt_inv',
#  'total_pymnt',
#  'mths_since_last_credit_pull_d',
#  'int_rate',
#  'out_prncp',
#  'out_prncp_inv',
#  'last_pymnt_amnt',
#  'mths_since_issue_d',
#  'dti',
#  'inq_last_6mths',
#  'term',
#  'tot_cur_bal',
#  'annual_inc',
#  'total_rev_hi_lim',
#  'revol_util',
#  'mths_since_earliest_cr_line',
#  'total_rec_int',
#  'emp_length',
#  'revol_bal',
#  'installment',
#  'total_acc',
#  'loan_amnt',
#  'funded_amnt_inv',
#  'funded_amnt',
#  'pub_rec',
#  'tot_coll_amt',
#  'delinq_2yrs']

# %%
corrmat = X_train_num[train_features].corr()
corrr(corrmat)

# %% [markdown]
# The following features can also be safely dropped given their multicollinearity with other features (> 0.7 or < -0.7):
# * total_pymnt_inv
# * total_pymnt
# * total_rec_int
# * installment
# * funded_amnt
# * funded_amnt_inv
# * total_rev_hi_lim
# * out_prncp_inv

# %%
columns_list = ["total_pymnt_inv","total_pymnt","total_rec_int", "installment",
                "funded_amnt","funded_amnt_inv","total_rev_hi_lim","out_prncp_inv"]

# %%
col_to_drop(X_train, columns_list)
col_to_drop(X_test, columns_list)

# %%
print(f"training shapes: {X_train.shape}, {y_train.shape}")
print(f"testing shapes: {X_test.shape}, {y_test.shape}")
# Out:
# training shapes: (316647, 95), (316647,)
# testing shapes: (93257, 95), (93257,)

# %% [markdown]
# <div id="seven">
#     <div style="font-size:25pt;color:red;font-weight:700;padding:20px 0;line-height:1.2">7. Model Selection and Building</div>
#     <div style="text-align: right;"><a href="#toc" style="text-decoration:none;">↑ Table of Contents</a></div>
# </div>

# %% [markdown]
# <div id="trainml">
#     <div style="font-size:20pt;font-weight:700;padding:20px 0;line-height:1.2">7.1 Training the Machine Learning Model</div>
#     <div style="text-align: right;"><a href="#toc" style="text-decoration:none;">↑ Table of Contents</a></div>
# </div>

# %%
X_train.iloc[:, 0:20].head(1)
# Out:
#         loan_amnt  term  int_rate  emp_length  annual_inc    dti  delinq_2yrs  \
# 237449      23975    60     12.99        10.0     48000.0  25.05          0.0
#
#         inq_last_6mths  pub_rec  revol_bal  revol_util  total_acc  out_prncp  \
# 237449             0.0      0.0       3947        23.9       17.0    20007.6
#
#         last_pymnt_amnt  tot_coll_amt  tot_cur_bal  \
# 237449           545.39           0.0      20191.0
#
#         mths_since_earliest_cr_line  mths_since_issue_d  \
# 237449                        343.0               102.0
#
#         mths_since_last_pymnt_d  mths_since_last_credit_pull_d
# 237449                     89.0                           89.0

# %%
X_train.iloc[:, 20:].head(1)
# Out:
#         grade:B  grade:C  grade:D  grade:E  grade:F  grade:G  \
# 237449        0        1        0        0        0        0
#
#         home_ownership:MORTGAGE  home_ownership:NONE  home_ownership:OTHER  \
# 237449                        1                    0                     0
#
#         home_ownership:OWN  ...  addr_state:TN  addr_state:TX  addr_state:UT  \
# 237449                   0  ...              0              0              0
#
#         addr_state:VA  addr_state:VT  addr_state:WA  addr_state:WI  \
# 237449              0              0              0              0
#
#         addr_state:WV  addr_state:WY  initial_list_status:w
# 237449              0              0                      1
#
# [1 rows x 75 columns]

# %%
numerical_ix = X_train.iloc[:, 0:20].columns
categorical_ix = X_train.iloc[:, 20:].columns

# %%
model_df={}

# %% [markdown]
# ### 1. Logistic Regression

# %%
# %%time
model = linear_model.LogisticRegression()
pipeline = model_val(model, model_df, X_train, y_train, numerical_ix, categorical_ix)
# Out:
# LogisticRegression() - X_train, y_train - AUROC: 0.95
# LogisticRegression() - X_train, y_train - GINI: 0.90
# Pipeline(steps=[('prep',
#                  ColumnTransformer(transformers=[('num', RobustScaler(),
#                                                   Index(['loan_amnt', 'term', 'int_rate', 'emp_length', 'annual_inc', 'dti',
#        'delinq_2yrs', 'inq_last_6mths', 'pub_rec', 'revol_bal', 'revol_util',
#        'total_acc', 'out_prncp', 'last_pymnt_amnt', 'tot_coll_amt',
#        'tot_cur_bal', 'mths_since_earliest_cr_line', 'mths_since_issue_d',
#        'mths_since_las...
#        'addr_state:NM', 'addr_state:NV', 'addr_state:NY', 'addr_state:OH',
#        'addr_state:OK', 'addr_state:OR', 'addr_state:PA', 'addr_state:RI',
#        'addr_state:SC', 'addr_state:SD', 'addr_state:TN', 'addr_state:TX',
#        'addr_state:UT', 'addr_state:VA', 'addr_state:VT', 'addr_state:WA',
#        'addr_state:WI', 'addr_state:WV', 'addr_state:WY',
#        'initial_list_status:w'],
# ...

# %% [markdown]
# ### 2. Ridge Classifier

# %%
# %%time
model = linear_model.RidgeClassifier()
pipeline = model_val(model, model_df, X_train, y_train, numerical_ix, categorical_ix)
# Out:
# RidgeClassifier() - X_train, y_train - AUROC: 0.91
# RidgeClassifier() - X_train, y_train - GINI: 0.82
# Pipeline(steps=[('prep',
#                  ColumnTransformer(transformers=[('num', RobustScaler(),
#                                                   Index(['loan_amnt', 'term', 'int_rate', 'emp_length', 'annual_inc', 'dti',
#        'delinq_2yrs', 'inq_last_6mths', 'pub_rec', 'revol_bal', 'revol_util',
#        'total_acc', 'out_prncp', 'last_pymnt_amnt', 'tot_coll_amt',
#        'tot_cur_bal', 'mths_since_earliest_cr_line', 'mths_since_issue_d',
#        'mths_since_las...
#        'addr_state:NM', 'addr_state:NV', 'addr_state:NY', 'addr_state:OH',
#        'addr_state:OK', 'addr_state:OR', 'addr_state:PA', 'addr_state:RI',
#        'addr_state:SC', 'addr_state:SD', 'addr_state:TN', 'addr_state:TX',
#        'addr_state:UT', 'addr_state:VA', 'addr_state:VT', 'addr_state:WA',
#        'addr_state:WI', 'addr_state:WV', 'addr_state:WY',
#        'initial_list_status:w'],
# ...

# %% [markdown]
# ### 3. SGD Classifier

# %%
# %%time
model = linear_model.SGDClassifier()
pipeline = model_val(model, model_df, X_train, y_train, numerical_ix, categorical_ix)
# Out:
# SGDClassifier() - X_train, y_train - AUROC: 0.86
# SGDClassifier() - X_train, y_train - GINI: 0.72
# Pipeline(steps=[('prep',
#                  ColumnTransformer(transformers=[('num', RobustScaler(),
#                                                   Index(['loan_amnt', 'term', 'int_rate', 'emp_length', 'annual_inc', 'dti',
#        'delinq_2yrs', 'inq_last_6mths', 'pub_rec', 'revol_bal', 'revol_util',
#        'total_acc', 'out_prncp', 'last_pymnt_amnt', 'tot_coll_amt',
#        'tot_cur_bal', 'mths_since_earliest_cr_line', 'mths_since_issue_d',
#        'mths_since_las...
#        'addr_state:NM', 'addr_state:NV', 'addr_state:NY', 'addr_state:OH',
#        'addr_state:OK', 'addr_state:OR', 'addr_state:PA', 'addr_state:RI',
#        'addr_state:SC', 'addr_state:SD', 'addr_state:TN', 'addr_state:TX',
#        'addr_state:UT', 'addr_state:VA', 'addr_state:VT', 'addr_state:WA',
#        'addr_state:WI', 'addr_state:WV', 'addr_state:WY',
#        'initial_list_status:w'],
# ...

# %% [markdown]
# ### 4. PassiveAggressiveClassifier

# %%
# %%time
model = linear_model.PassiveAggressiveClassifier()
pipeline = model_val(model, model_df, X_train, y_train, numerical_ix, categorical_ix)
# Out:
# PassiveAggressiveClassifier() - X_train, y_train - AUROC: 0.87
# PassiveAggressiveClassifier() - X_train, y_train - GINI: 0.74
# Pipeline(steps=[('prep',
#                  ColumnTransformer(transformers=[('num', RobustScaler(),
#                                                   Index(['loan_amnt', 'term', 'int_rate', 'emp_length', 'annual_inc', 'dti',
#        'delinq_2yrs', 'inq_last_6mths', 'pub_rec', 'revol_bal', 'revol_util',
#        'total_acc', 'out_prncp', 'last_pymnt_amnt', 'tot_coll_amt',
#        'tot_cur_bal', 'mths_since_earliest_cr_line', 'mths_since_issue_d',
#        'mths_since_las...
#        'addr_state:NM', 'addr_state:NV', 'addr_state:NY', 'addr_state:OH',
#        'addr_state:OK', 'addr_state:OR', 'addr_state:PA', 'addr_state:RI',
#        'addr_state:SC', 'addr_state:SD', 'addr_state:TN', 'addr_state:TX',
#        'addr_state:UT', 'addr_state:VA', 'addr_state:VT', 'addr_state:WA',
#        'addr_state:WI', 'addr_state:WV', 'addr_state:WY',
# ...

# %% [markdown]
# ### 5. Linear Discriminant Analysis

# %%
# %%time
model = discriminant_analysis.LinearDiscriminantAnalysis()
pipeline = model_val(model, model_df, X_train, y_train, numerical_ix, categorical_ix)
# Out:
# LinearDiscriminantAnalysis() - X_train, y_train - AUROC: 0.91
# LinearDiscriminantAnalysis() - X_train, y_train - GINI: 0.82
# Pipeline(steps=[('prep',
#                  ColumnTransformer(transformers=[('num', RobustScaler(),
#                                                   Index(['loan_amnt', 'term', 'int_rate', 'emp_length', 'annual_inc', 'dti',
#        'delinq_2yrs', 'inq_last_6mths', 'pub_rec', 'revol_bal', 'revol_util',
#        'total_acc', 'out_prncp', 'last_pymnt_amnt', 'tot_coll_amt',
#        'tot_cur_bal', 'mths_since_earliest_cr_line', 'mths_since_issue_d',
#        'mths_since_las...
#        'addr_state:NM', 'addr_state:NV', 'addr_state:NY', 'addr_state:OH',
#        'addr_state:OK', 'addr_state:OR', 'addr_state:PA', 'addr_state:RI',
#        'addr_state:SC', 'addr_state:SD', 'addr_state:TN', 'addr_state:TX',
#        'addr_state:UT', 'addr_state:VA', 'addr_state:VT', 'addr_state:WA',
#        'addr_state:WI', 'addr_state:WV', 'addr_state:WY',
# ...

# %% [markdown]
# ### 6. Quadratic Discriminant Analysis

# %%
# %%time
model = discriminant_analysis.QuadraticDiscriminantAnalysis()
pipeline = model_val(model, model_df, X_train, y_train, numerical_ix, categorical_ix)
# Out:
# QuadraticDiscriminantAnalysis() - X_train, y_train - AUROC: 0.86
# QuadraticDiscriminantAnalysis() - X_train, y_train - GINI: 0.72
# Pipeline(steps=[('prep',
#                  ColumnTransformer(transformers=[('num', RobustScaler(),
#                                                   Index(['loan_amnt', 'term', 'int_rate', 'emp_length', 'annual_inc', 'dti',
#        'delinq_2yrs', 'inq_last_6mths', 'pub_rec', 'revol_bal', 'revol_util',
#        'total_acc', 'out_prncp', 'last_pymnt_amnt', 'tot_coll_amt',
#        'tot_cur_bal', 'mths_since_earliest_cr_line', 'mths_since_issue_d',
#        'mths_since_las...
#        'addr_state:NM', 'addr_state:NV', 'addr_state:NY', 'addr_state:OH',
#        'addr_state:OK', 'addr_state:OR', 'addr_state:PA', 'addr_state:RI',
#        'addr_state:SC', 'addr_state:SD', 'addr_state:TN', 'addr_state:TX',
#        'addr_state:UT', 'addr_state:VA', 'addr_state:VT', 'addr_state:WA',
#        'addr_state:WI', 'addr_state:WV', 'addr_state:WY',
# ...

# %% [markdown]
# ### 7. Decision Tree

# %%
# %%time
model = tree.DecisionTreeClassifier()
pipeline = model_val(model, model_df, X_train, y_train, numerical_ix, categorical_ix)
# Out:
# DecisionTreeClassifier() - X_train, y_train - AUROC: 0.94
# DecisionTreeClassifier() - X_train, y_train - GINI: 0.88
# Pipeline(steps=[('prep',
#                  ColumnTransformer(transformers=[('num', RobustScaler(),
#                                                   Index(['loan_amnt', 'term', 'int_rate', 'emp_length', 'annual_inc', 'dti',
#        'delinq_2yrs', 'inq_last_6mths', 'pub_rec', 'revol_bal', 'revol_util',
#        'total_acc', 'out_prncp', 'last_pymnt_amnt', 'tot_coll_amt',
#        'tot_cur_bal', 'mths_since_earliest_cr_line', 'mths_since_issue_d',
#        'mths_since_las...
#        'addr_state:NM', 'addr_state:NV', 'addr_state:NY', 'addr_state:OH',
#        'addr_state:OK', 'addr_state:OR', 'addr_state:PA', 'addr_state:RI',
#        'addr_state:SC', 'addr_state:SD', 'addr_state:TN', 'addr_state:TX',
#        'addr_state:UT', 'addr_state:VA', 'addr_state:VT', 'addr_state:WA',
#        'addr_state:WI', 'addr_state:WV', 'addr_state:WY',
# ...

# %% [markdown]
# ### 8. Extra Tree

# %%
# %%time
model = tree.ExtraTreeClassifier()
pipeline = model_val(model, model_df, X_train, y_train, numerical_ix, categorical_ix)
# Out:
# ExtraTreeClassifier() - X_train, y_train - AUROC: 0.75
# ExtraTreeClassifier() - X_train, y_train - GINI: 0.51
# Pipeline(steps=[('prep',
#                  ColumnTransformer(transformers=[('num', RobustScaler(),
#                                                   Index(['loan_amnt', 'term', 'int_rate', 'emp_length', 'annual_inc', 'dti',
#        'delinq_2yrs', 'inq_last_6mths', 'pub_rec', 'revol_bal', 'revol_util',
#        'total_acc', 'out_prncp', 'last_pymnt_amnt', 'tot_coll_amt',
#        'tot_cur_bal', 'mths_since_earliest_cr_line', 'mths_since_issue_d',
#        'mths_since_las...
#        'addr_state:NM', 'addr_state:NV', 'addr_state:NY', 'addr_state:OH',
#        'addr_state:OK', 'addr_state:OR', 'addr_state:PA', 'addr_state:RI',
#        'addr_state:SC', 'addr_state:SD', 'addr_state:TN', 'addr_state:TX',
#        'addr_state:UT', 'addr_state:VA', 'addr_state:VT', 'addr_state:WA',
#        'addr_state:WI', 'addr_state:WV', 'addr_state:WY',
#        'initial_list_status:w'],
# ...

# %% [markdown]
# ### 9. Ada Boost

# %%
# %%time
model = ensemble.AdaBoostClassifier()
pipeline = model_val(model, model_df, X_train, y_train, numerical_ix, categorical_ix)
# Out:
# AdaBoostClassifier() - X_train, y_train - AUROC: 0.98
# AdaBoostClassifier() - X_train, y_train - GINI: 0.97
# Pipeline(steps=[('prep',
#                  ColumnTransformer(transformers=[('num', RobustScaler(),
#                                                   Index(['loan_amnt', 'term', 'int_rate', 'emp_length', 'annual_inc', 'dti',
#        'delinq_2yrs', 'inq_last_6mths', 'pub_rec', 'revol_bal', 'revol_util',
#        'total_acc', 'out_prncp', 'last_pymnt_amnt', 'tot_coll_amt',
#        'tot_cur_bal', 'mths_since_earliest_cr_line', 'mths_since_issue_d',
#        'mths_since_las...
#        'addr_state:NM', 'addr_state:NV', 'addr_state:NY', 'addr_state:OH',
#        'addr_state:OK', 'addr_state:OR', 'addr_state:PA', 'addr_state:RI',
#        'addr_state:SC', 'addr_state:SD', 'addr_state:TN', 'addr_state:TX',
#        'addr_state:UT', 'addr_state:VA', 'addr_state:VT', 'addr_state:WA',
#        'addr_state:WI', 'addr_state:WV', 'addr_state:WY',
#        'initial_list_status:w'],
# ...

# %% [markdown]
# ### 10. Gaussian NB

# %%
# %%time
model = naive_bayes.GaussianNB()
pipeline = model_val(model, model_df, X_train, y_train, numerical_ix, categorical_ix)
# Out:
# GaussianNB() - X_train, y_train - AUROC: 0.83
# GaussianNB() - X_train, y_train - GINI: 0.67
# Pipeline(steps=[('prep',
#                  ColumnTransformer(transformers=[('num', RobustScaler(),
#                                                   Index(['loan_amnt', 'term', 'int_rate', 'emp_length', 'annual_inc', 'dti',
#        'delinq_2yrs', 'inq_last_6mths', 'pub_rec', 'revol_bal', 'revol_util',
#        'total_acc', 'out_prncp', 'last_pymnt_amnt', 'tot_coll_amt',
#        'tot_cur_bal', 'mths_since_earliest_cr_line', 'mths_since_issue_d',
#        'mths_since_las...
#        'addr_state:NM', 'addr_state:NV', 'addr_state:NY', 'addr_state:OH',
#        'addr_state:OK', 'addr_state:OR', 'addr_state:PA', 'addr_state:RI',
#        'addr_state:SC', 'addr_state:SD', 'addr_state:TN', 'addr_state:TX',
#        'addr_state:UT', 'addr_state:VA', 'addr_state:VT', 'addr_state:WA',
#        'addr_state:WI', 'addr_state:WV', 'addr_state:WY',
#        'initial_list_status:w'],
# ...

# %% [markdown]
# ### 11. LightGBM

# %%
# %%time
model = lgb.LGBMClassifier()
pipeline = model_val(model, model_df, X_train, y_train, numerical_ix, categorical_ix)
# Out:
# LGBMClassifier() - X_train, y_train - AUROC: 0.99
# LGBMClassifier() - X_train, y_train - GINI: 0.98
# Pipeline(steps=[('prep',
#                  ColumnTransformer(transformers=[('num', RobustScaler(),
#                                                   Index(['loan_amnt', 'term', 'int_rate', 'emp_length', 'annual_inc', 'dti',
#        'delinq_2yrs', 'inq_last_6mths', 'pub_rec', 'revol_bal', 'revol_util',
#        'total_acc', 'out_prncp', 'last_pymnt_amnt', 'tot_coll_amt',
#        'tot_cur_bal', 'mths_since_earliest_cr_line', 'mths_since_issue_d',
#        'mths_since_las...
#        'addr_state:NM', 'addr_state:NV', 'addr_state:NY', 'addr_state:OH',
#        'addr_state:OK', 'addr_state:OR', 'addr_state:PA', 'addr_state:RI',
#        'addr_state:SC', 'addr_state:SD', 'addr_state:TN', 'addr_state:TX',
#        'addr_state:UT', 'addr_state:VA', 'addr_state:VT', 'addr_state:WA',
#        'addr_state:WI', 'addr_state:WV', 'addr_state:WY',
#        'initial_list_status:w'],
# ...

# %% [markdown]
# <div id="selectml">
#     <div style="font-size:20pt;font-weight:700;padding:20px 0;line-height:1.2">7.2 Selecting the Machine Learning Model</div>
#     <div style="text-align: right;"><a href="#toc" style="text-decoration:none;">↑ Table of Contents</a></div>
# </div>

# %%
model_df
# Out:
# {LogisticRegression(): 0.95,
#  RidgeClassifier(): 0.91,
#  SGDClassifier(): 0.86,
#  PassiveAggressiveClassifier(): 0.87,
#  LinearDiscriminantAnalysis(): 0.91,
#  QuadraticDiscriminantAnalysis(): 0.86,
#  DecisionTreeClassifier(): 0.94,
#  ExtraTreeClassifier(): 0.75,
#  AdaBoostClassifier(): 0.98,
#  GaussianNB(): 0.83,
#  LGBMClassifier(): 0.99}

# %% [markdown]
# It is evident that the **LGBM Classifier** Model outperforms the others with an impressive AUROC score of approximately **0.99**. Therefore, we will proceed with this model and delve deeper into its analysis.

# %%
# %%time
model = lgb.LGBMClassifier()
pipeline = model_val(model, model_df, X_train, y_train, numerical_ix, categorical_ix)
# Out:
# LGBMClassifier() - X_train, y_train - AUROC: 0.99
# LGBMClassifier() - X_train, y_train - GINI: 0.98
# Pipeline(steps=[('prep',
#                  ColumnTransformer(transformers=[('num', RobustScaler(),
#                                                   Index(['loan_amnt', 'term', 'int_rate', 'emp_length', 'annual_inc', 'dti',
#        'delinq_2yrs', 'inq_last_6mths', 'pub_rec', 'revol_bal', 'revol_util',
#        'total_acc', 'out_prncp', 'last_pymnt_amnt', 'tot_coll_amt',
#        'tot_cur_bal', 'mths_since_earliest_cr_line', 'mths_since_issue_d',
#        'mths_since_las...
#        'addr_state:NM', 'addr_state:NV', 'addr_state:NY', 'addr_state:OH',
#        'addr_state:OK', 'addr_state:OR', 'addr_state:PA', 'addr_state:RI',
#        'addr_state:SC', 'addr_state:SD', 'addr_state:TN', 'addr_state:TX',
#        'addr_state:UT', 'addr_state:VA', 'addr_state:VT', 'addr_state:WA',
#        'addr_state:WI', 'addr_state:WV', 'addr_state:WY',
#        'initial_list_status:w'],
# ...

# %% [markdown]
# <div id="featureimportance">
#     <div style="font-size:20pt;font-weight:700;padding:20px 0;line-height:1.2">7.3 Feature Importance</div>
#     <div style="text-align: right;"><a href="#toc" style="text-decoration:none;">↑ Table of Contents</a></div>
# </div>

# %%
feature_importance = model.feature_importances_
feature_names = X_train.columns

sns.set_style("whitegrid")
plt.figure(figsize=(10, 20))
plt.grid(False)
plt.gca().spines["right"].set_visible(False)
plt.gca().spines["top"].set_visible(False)
plt.barh(feature_names, feature_importance)
plt.xlabel("Feature Importance")
plt.ylabel("Feature")
plt.title("LGBM Classifier - Feature Importance")
plt.show()

# %%
feature_importance = model.feature_importances_
feature_names = X_train.columns

sorted_indices = np.argsort(feature_importance)[::-1]
sorted_importance = feature_importance[sorted_indices]
sorted_names = [feature_names[i] for i in sorted_indices]

top_20_indices = sorted_indices[:20]
top_20_importance = sorted_importance[:20]
top_20_names = sorted_names[:20]

sns.set_style("whitegrid")
plt.figure(figsize=(10, 8))
plt.grid(False)
plt.gca().spines["right"].set_visible(False)
plt.gca().spines["top"].set_visible(False)
plt.barh(top_20_names, top_20_importance)
plt.xlabel("Feature Importance")
plt.ylabel("Feature")
plt.title("Top 20 Features - LGBM Classifier")
plt.show()

# %% [markdown]
# <div id="testml">
#     <div style="font-size:20pt;font-weight:700;padding:20px 0;line-height:1.2">7.4 Testing the Machine Learning Model</div>
#     <div style="text-align: right;"><a href="#toc" style="text-decoration:none;">↑ Table of Contents</a></div>
# </div>

# %%
y_hat_test = pipeline.predict(X_test)
y_hat_test_proba = pipeline.predict_proba(X_test)
y_hat_test_proba
# Out:
# array([[2.17983847e-02, 9.78201615e-01],
#        [4.50835149e-05, 9.99954916e-01],
#        [4.00589059e-03, 9.95994109e-01],
#        ...,
#        [1.16521968e-02, 9.88347803e-01],
#        [5.18901699e-03, 9.94810983e-01],
#        [4.03721600e-03, 9.95962784e-01]])

# %%
# select the probabilities of only the positive class
y_hat_test_proba = y_hat_test_proba[:][: , 1]

# %%
y_test_temp = y_test.copy()
y_test_temp.reset_index(drop = True, inplace = True)
y_test_proba = pd.concat([y_test_temp, pd.DataFrame(y_hat_test_proba)], axis = 1)

y_test_proba.shape, y_test.shape
# Out:
# ((93257, 2), (93257,))

# %%
y_test_proba.columns = ["y_test_class_actual", "y_hat_test_proba"]

y_test_proba.index = X_test.index
y_test_proba.head()
# Out:
#         y_test_class_actual  y_hat_test_proba
# 72790                     1          0.978202
# 313190                    1          0.999955
# 131467                    1          0.995994
# 202216                    1          0.995601
# 366633                    1          0.994436

# %% [markdown]
# <div id="confmatrixauroctest">
#     <div style="font-size:20pt;font-weight:700;padding:20px 0;line-height:1.2">7.5 Confusion Matrix and AUROC on X_test Set</div>
#     <div style="text-align: right;"><a href="#toc" style="text-decoration:none;">↑ Table of Contents</a></div>
# </div>

# %%
# threshold
tr = 0.5

y_test_proba["y_test_class_predicted"] = np.where(y_test_proba["y_hat_test_proba"] > tr, 1, 0)
cm = metrics.confusion_matrix(y_test_proba["y_test_class_actual"], y_test_proba["y_test_class_predicted"], normalize="all")
True_Pos, True_Neg, False_Pos, False_Neg = confusion_matrix_mod(cm)

# %%
fpr, tpr, thresholds = metrics.roc_curve(y_test_proba["y_test_class_actual"], y_test_proba["y_hat_test_proba"])
sns.set()
plt.plot(fpr, tpr)
plt.plot(fpr, fpr, linestyle = "--", color = "k")
plt.xlabel("False positive rate")
plt.ylabel("True positive rate")
plt.title("ROC curve");

# %%
# calculate the no skill line as the proportion of the positive class
no_skill = len(y_test[y_test == 1]) / len(y)

plt.plot([0, 1], [no_skill, no_skill], linestyle="--", label="No Skill")

precision, recall, thresholds = metrics.precision_recall_curve(y_test_proba["y_test_class_actual"], y_test_proba["y_hat_test_proba"])

plt.plot(recall, precision, marker=".", label="Logistic")
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.legend()
plt.title("PR curve");

# %%
results = pd.DataFrame(evaluation(y_test_proba,tr,"y_test_class_actual","y_test_class_predicted","y_hat_test_proba",recall,precision), index=[0])
results
# Out:
#    Threshold  Accuracy  Precision   Recall        F1     AUROC      Gini  \
# 0        0.5  0.948154   0.991506  0.94993  0.970273  0.983606  0.967211
#
#       AUCPR
# 0  0.997538

# %% [markdown]
# <div id="loancutoffs">
#     <div style="font-size:20pt;font-weight:700;padding:20px 0;line-height:1.2">7.6 Setting loan approval cut-offs</div>
#     <div style="text-align: right;"><a href="#toc" style="text-decoration:none;">↑ Table of Contents</a></div>
# </div>

# %%
# J = tpr - fpr

# ix = np.argmax(J)
# best_thresh = thresholds[ix]
# print('Best Threshold: %f' % (best_thresh))

# %%
# tr = best_thresh

# %%
# y_test_proba["y_test_class_predicted"] = np.where(y_test_proba["y_hat_test_proba"] > tr, 1, 0)
# cm = metrics.confusion_matrix(y_test_proba["y_test_class_actual"], y_test_proba["y_test_class_predicted"], normalize="all")
# True_Pos, True_Neg, False_Pos, False_Neg = confusion_matrix_mod(cm)

# %% [markdown]
# <div id="calmoneysavedandlosses">
#     <div style="font-size:20pt;font-weight:700;padding:20px 0;line-height:1.2">7.7 Calculating Money Saved and Losses in the X_test set</div>
#     <div style="text-align: right;"><a href="#toc" style="text-decoration:none;">↑ Table of Contents</a></div>
# </div>

# %%
cols = {"id": IDs,
        "Thresholds": tr,
        "y prob. prediction": y_test_proba["y_hat_test_proba"],
        "Loan Amount": Loan_Amount,
        "Loan Status": y_test_proba["y_hat_test_proba"] \
                              .apply(lambda x: "Rejected" if x < tr else "Accepted")}

# %%
final_table = pd.DataFrame(cols)
final_table.head(20)
# Out:
#               id  Thresholds  y prob. prediction  Loan Amount Loan Status
# 72790    8296051         0.5            0.978202         6000    Accepted
# 313190  26178608         0.5            0.999955        15000    Accepted
# 131467   5606947         0.5            0.995994        19200    Accepted
# 202216   1481711         0.5            0.995601        15000    Accepted
# 366633  19105816         0.5            0.994436         6000    Accepted
# 97503    6805709         0.5            0.999906         6000    Accepted
# 334966  21199998         0.5            0.976081        35000    Accepted
# 371589   7083236         0.5            0.998067         9200    Accepted
# 176433   2837533         0.5            0.993412        17000    Accepted
# 52034    9414608         0.5            0.996680        12000    Accepted
# 265088  31999151         0.5            0.997215        15000    Accepted
# 458233  10626953         0.5            0.997343        10000    Accepted
# ...

# %%
total_accepted = len(final_table[final_table["Loan Status"] == "Accepted"])
total_rejected = len(final_table[final_table["Loan Status"] == "Rejected"])

acceptance_rate = total_accepted / len(final_table)
rejection_rate = total_rejected / len(final_table)

money_saved = (final_table["Loan Amount"]*((final_table["Loan Status"] == "Accepted").astype(int))).sum()*(True_Pos+True_Neg)
money_losses = (final_table["Loan Amount"]*((final_table["Loan Status"] == "Rejected").astype(int))).sum()*(False_Pos+False_Neg)

results = pd.DataFrame({"Total Applicants": [total_accepted+total_rejected],
                        "Total Accepted": [total_accepted],
                        "Total Rejected": [total_rejected],
                        "Acceptance Rate": "{:.2f}%".format(acceptance_rate*100),
                        "Rejection Rate": "{:.2f}%".format(rejection_rate*100),
                        "TP+TN": "{:.2f}%".format((True_Pos+True_Neg)*100),
                        "FP+FN": "{:.2f}%".format((False_Pos+False_Neg)*100),
                        "Money Saved (USD)": "{:.2e}".format(money_saved),
                        "Money Losses (USD)": "{:.2e}".format(money_losses)})
results
# Out:
#    Total Applicants  Total Accepted  Total Rejected Acceptance Rate  \
# 0             93257           79581           13676          85.34%
#
#   Rejection Rate   TP+TN  FP+FN Money Saved (USD) Money Losses (USD)
# 0         14.66%  94.82%  5.18%          1.09e+09           9.44e+06

# %% [markdown]
# * True Positive (TP): If my machine predicts that the applicant will not default, and they actually do not default.
# * True Negative (TN): If my machine predicts that the applicant will default, and they actually do default.
# * False Positive (FP): If my machine predicts that the applicant will not default, but they actually do default.
# * False Negative (FN): If my machine predicts that the applicant will default, but they actually do not default.

# %% [markdown]
# So, the company will save approximately 1,000,000,000 USD and will lose approximately 9,000,000 USD.
#
# These variables depend on the quality of metrics from my machine learning model, such as threshold, accuracy, precision, recall, F1 score, AUROC, Gini, and AUCPR. The results of this project are threshold = 0.5, accuracy = 0.95, precision = 0.99, recall = 0.95, F1 = 0.97, AUROC = 0.98, Gini = 0.97, and AUCPR = 0.99. These metrics are very good for credit risk modeling.

# %%
final_table.to_csv("submission.csv", index=False)

# %% [markdown]
# ## References
#
# * https://github.com/jihadakbr/credit-score-prediction
# * https://towardsdatascience.com/how-to-develop-a-credit-risk-model-and-scorecard-91335fc01f03
# * https://www.kaggle.com/code/chandrimad31/credit-risk-part-1-binning-woe-iv-pd-model
# * https://www.listendata.com/2015/03/weight-of-evidence-woe-and-information.html
# * https://www.analyticsvidhya.com/blog/2021/06/understand-weight-of-evidence-and-information-value/
# * https://www.analyticsvidhya.com/blog/2020/06/auc-roc-curve-machine-learning/
# * https://medium.com/mlearning-ai/weight-of-evidence-woe-and-information-value-iv-how-to-use-it-in-eda-and-model-building-3b3b98efe0e8
